# %%
import tkinter as tk
from tkinter import messagebox

def WelcomeMessage1(course):
    window = tk.Toplevel(root)
    window.title("Course")
    window.geometry("1000x500")
    label_1 = tk.Label(window, text=f"{course}")
    label_1.pack()

    if course == "Computer Science":
        WelcomeMessage2("Admitted")
    elif course == "Mass Communication":
        WelcomeMessage3("Admitted")

def WelcomeMessage2(admission):
    window = tk.Toplevel(root)
    window.title("Admission Status")
    window.geometry("1000x500")
    label_1 = tk.Label(window, text=f"STATUS: {admission}")
    label_1.pack()
    

def WelcomeMessage3(admission):
    window = tk.Toplevel(root)
    window.title("Admission Status")
    window.geometry("1000x500")
    label_1 = tk.Label(window, text=f"STATUS: {admission}")
    label_1.pack()

def enter():
    course = course_entry.get()
    interview = interview_entry.get()
    jamb = int(jamb_entry.get())
    #("How many C's or above")
    grade = int(grade_entry.get())

    if course == "Computer Science" and jamb >= 250 and grade >= 5 and interview == "Passed":
        admission = "Admitted"
        WelcomeMessage2(admission)
        admitted_array = [admission.split()]
        
    elif course == "Computer Science":
        admission = "NOT Admitted"
        WelcomeMessage2(admission)
        notadmitted_array = [admission.split()]
        
    elif course == "Mass Communication" and jamb >=230 and grade >= 5 and interview =="Passed":
        admission = "Admitted"
        WelcomeMessage3(admission)
        admitted_array = [admission.split()]
        
    elif course == "Mass Communication":
        admission = "NOT Admitted"
        WelcomeMessage3(admission)
        notadmitted_array = [admission.split()]
        
    else:
        messagebox.showerror("Error", "Course does not exist")

root = tk.Tk()
root.title("Login form")
root.geometry("500x200")
course_label = tk.Label(root, text= "Course")
course_label.pack()
course_entry = tk.Entry(root)
course_entry.pack()

jamb_label = tk.Label(root, text= "Jamb")
jamb_label.pack()
jamb_entry = tk.Entry(root)
jamb_entry.pack()

grade_label = tk.Label(root, text= "Grade")
grade_label.pack()
grade_entry = tk.Entry(root)
grade_entry.pack()

interview_label = tk.Label(root, text= "Interview")
interview_label.pack()
interview_entry = tk.Entry(root)
interview_entry.pack()

enter_button = tk.Button(root, text= "Enter", command=enter)
enter_button.pack()
enter_button.config(fg= "green")

root.mainloop()
